# %%
import tensorflow as tf
import tensorflow_datasets as tfds
tfds.disable_progress_bar()

import math
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline 

import logging
logger = tf.get_logger()
logger.setLevel(logging.ERROR)

dataset, metadata = tfds.load("fashion_mnist", as_supervised=True, with_info=True)
train_dataset, test_dataset = dataset["train"], dataset["test"]

class_names = metadata.features["label"].names
print("Class names: {}".format(class_names))

num_train_examples = metadata.splits["train"].num_examples
num_test_examples = metadata.splits["test"].num_examples
print(num_train_examples, num_test_examples)


def normalize(images, labels):
    images = tf.cast(images, tf.float32)
    images /= 255
    return images, labels


train_dataset = train_dataset.map(normalize)
test_dataset = test_dataset.map(normalize)
train_dataset = train_dataset.cache()
test_dataset = test_dataset.cache()
# Out:
# 2021-09-18 05:36:40.080825: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# Class names: ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat', 'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']
# 60000 10000
# 2021-09-18 05:36:41.137238: I tensorflow/compiler/jit/xla_cpu_device.cc:41] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2021-09-18 05:36:41.137682: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcuda.so.1
# 2021-09-18 05:36:41.182968: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-09-18 05:36:41.183391: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 0 with properties:
# pciBusID: 0000:01:00.0 name: NVIDIA GeForce RTX 2060 SUPER computeCapability: 7.5
# coreClock: 1.65GHz coreCount: 34 deviceMemorySize: 7.79GiB deviceMemoryBandwidth: 417.29GiB/s
# 2021-09-18 05:36:41.183416: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# 2021-09-18 05:36:41.185995: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.11
# 2021-09-18 05:36:41.186045: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublasLt.so.11
# 2021-09-18 05:36:41.186926: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcufft.so.10
# 2021-09-18 05:36:41.187136: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcurand.so.10
# 2021-09-18 05:36:41.189460: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusolver.so.10
# 2021-09-18 05:36:41.190044: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusparse.so.11
# 2021-09-18 05:36:41.190151: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudnn.so.8
# 2021-09-18 05:36:41.190231: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-09-18 05:36:41.190617: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-09-18 05:36:41.190945: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1862] Adding visible gpu devices: 0
# 2021-09-18 05:36:41.192146: I tensorflow/compiler/jit/xla_gpu_device.cc:99] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2021-09-18 05:36:41.192219: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-09-18 05:36:41.192549: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 0 with properties:
# pciBusID: 0000:01:00.0 name: NVIDIA GeForce RTX 2060 SUPER computeCapability: 7.5
# coreClock: 1.65GHz coreCount: 34 deviceMemorySize: 7.79GiB deviceMemoryBandwidth: 417.29GiB/s
# 2021-09-18 05:36:41.192567: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# 2021-09-18 05:36:41.192582: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublas.so.11
# 2021-09-18 05:36:41.192595: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcublasLt.so.11
# 2021-09-18 05:36:41.192607: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcufft.so.10
# 2021-09-18 05:36:41.192619: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcurand.so.10
# 2021-09-18 05:36:41.192631: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusolver.so.10
# 2021-09-18 05:36:41.192643: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcusparse.so.11
# 2021-09-18 05:36:41.192656: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudnn.so.8
# 2021-09-18 05:36:41.192701: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-09-18 05:36:41.193030: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-09-18 05:36:41.193316: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1862] Adding visible gpu devices: 0
# 2021-09-18 05:36:41.193341: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# 2021-09-18 05:36:41.507290: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1261] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2021-09-18 05:36:41.507309: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1267]      0
# 2021-09-18 05:36:41.507314: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1280] 0:   N
# 2021-09-18 05:36:41.507436: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-09-18 05:36:41.507687: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-09-18 05:36:41.507910: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-09-18 05:36:41.508118: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1406] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 7021 MB memory) -> physical GPU (device: 0, name: NVIDIA GeForce RTX 2060 SUPER, pci bus id: 0000:01:00.0, compute capability: 7.5)

# %%
for image, label in test_dataset.take(1):
    break
image = image.numpy().reshape((28,28))
plt.figure()
plt.imshow(image, cmap=plt.cm.binary)
plt.colorbar()
plt.grid(False)
plt.show()
# Out:
# 2021-09-18 05:38:53.287388: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:116] None of the MLIR optimization passes are enabled (registered 2)
# 2021-09-18 05:38:53.304922: I tensorflow/core/platform/profile_utils/cpu_utils.cc:112] CPU Frequency: 2899885000 Hz
# 2021-09-18 05:38:53.321434: W tensorflow/core/kernels/data/cache_dataset_ops.cc:757] The calling iterator did not fully read the dataset being cached. In order to avoid unexpected truncation of the dataset, the partially cached contents of the dataset will be discarded. This can happen if you have an input pipeline similar to `dataset.cache().take(k).repeat()`. You should use `dataset.take(k).cache().repeat()` instead.
# 2021-09-18 05:38:53.321493: W tensorflow/core/kernels/data/cache_dataset_ops.cc:757] The calling iterator did not fully read the dataset being cached. In order to avoid unexpected truncation of the dataset, the partially cached contents of the dataset will be discarded. This can happen if you have an input pipeline similar to `dataset.cache().take(k).repeat()`. You should use `dataset.take(k).cache().repeat()` instead.

# %%
plt.figure(figsize=(10,10))
for i, (image, label) in enumerate(train_dataset.take(25)):
    image = image.numpy().reshape((28,28))
    plt.subplot(5, 5, i + 1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(image, cmap=plt.cm.binary)
    plt.xlabel(class_names[label])
plt.show()
# Out:
# 2021-09-18 05:42:20.652949: W tensorflow/core/kernels/data/cache_dataset_ops.cc:757] The calling iterator did not fully read the dataset being cached. In order to avoid unexpected truncation of the dataset, the partially cached contents of the dataset will be discarded. This can happen if you have an input pipeline similar to `dataset.cache().take(k).repeat()`. You should use `dataset.take(k).cache().repeat()` instead.
# 2021-09-18 05:42:20.652992: W tensorflow/core/kernels/data/cache_dataset_ops.cc:757] The calling iterator did not fully read the dataset being cached. In order to avoid unexpected truncation of the dataset, the partially cached contents of the dataset will be discarded. This can happen if you have an input pipeline similar to `dataset.cache().take(k).repeat()`. You should use `dataset.take(k).cache().repeat()` instead.

# %%
model = tf.keras.Sequential([
    tf.keras.layers.Flatten(input_shape = [28,28,1]),
    tf.keras.layers.Dense(128, activation=tf.nn.relu),
    tf.keras.layers.Dense(10, activation=tf.nn.softmax)
])

# %%
model.compile(optimizer="adam", loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=["accuracy"])

# %%
BATCH_SIZE = 32
train_dataset = train_dataset.cache().repeat().shuffle(num_train_examples).batch(BATCH_SIZE)
test_dataset = test_dataset.cache().batch(BATCH_SIZE)

# %%
model.fit(train_dataset, epochs=30, steps_per_epoch=math.ceil(num_train_examples/BATCH_SIZE))
# Out:
# Epoch 1/30
# 1875/1875 [==============================] - 2s 850us/step - loss: 1.5929 - accuracy: 0.8684
# Epoch 2/30
# 1875/1875 [==============================] - 2s 840us/step - loss: 1.5893 - accuracy: 0.8726
# Epoch 3/30
# 1875/1875 [==============================] - 2s 832us/step - loss: 1.5851 - accuracy: 0.8768
# Epoch 4/30
# 1875/1875 [==============================] - 2s 821us/step - loss: 1.5846 - accuracy: 0.8771
# Epoch 5/30
# 1875/1875 [==============================] - 2s 804us/step - loss: 1.5790 - accuracy: 0.8824
# Epoch 6/30
# 1875/1875 [==============================] - 2s 823us/step - loss: 1.5766 - accuracy: 0.8850
# Epoch 7/30
# 1875/1875 [==============================] - 2s 811us/step - loss: 1.5752 - accuracy: 0.8866
# Epoch 8/30
# 1875/1875 [==============================] - 2s 853us/step - loss: 1.5700 - accuracy: 0.8918
# Epoch 9/30
# 1875/1875 [==============================] - 1s 797us/step - loss: 1.5721 - accuracy: 0.8891
# Epoch 10/30
# 1875/1875 [==============================] - 2s 841us/step - loss: 1.5707 - accuracy: 0.8909
# Epoch 11/30
# 1875/1875 [==============================] - 2s 862us/step - loss: 1.5677 - accuracy: 0.8936
# Epoch 12/30
# 1875/1875 [==============================] - 2s 819us/step - loss: 1.5650 - accuracy: 0.8969
# Epoch 13/30
# 1875/1875 [==============================] - 2s 835us/step - loss: 1.5658 - accuracy: 0.8956
# Epoch 14/30
# 1875/1875 [==============================] - 2s 809us/step - loss: 1.5651 - accuracy: 0.8967
# Epoch 15/30
# 1875/1875 [==============================] - 2s 847us/step - loss: 1.5638 - accuracy: 0.8976
# Epoch 16/30
# 1875/1875 [==============================] - 2s 878us/step - loss: 1.5629 - accuracy: 0.8981
# Epoch 17/30
# 1875/1875 [==============================] - 2s 807us/step - loss: 1.5588 - accuracy: 0.9029
# Epoch 18/30
# 1875/1875 [==============================] - 2s 850us/step - loss: 1.5621 - accuracy: 0.8996
# Epoch 19/30
# 1875/1875 [==============================] - 2s 842us/step - loss: 1.5593 - accuracy: 0.9021
# Epoch 20/30
# 1875/1875 [==============================] - 2s 841us/step - loss: 1.5584 - accuracy: 0.9030
# Epoch 21/30
# 1875/1875 [==============================] - 2s 823us/step - loss: 1.5557 - accuracy: 0.9061
# Epoch 22/30
# 1875/1875 [==============================] - 2s 828us/step - loss: 1.5561 - accuracy: 0.9053
# Epoch 23/30
# 1875/1875 [==============================] - 2s 833us/step - loss: 1.5575 - accuracy: 0.9035
# Epoch 24/30
# 1875/1875 [==============================] - 2s 809us/step - loss: 1.5534 - accuracy: 0.9079
# Epoch 25/30
# 1875/1875 [==============================] - 2s 826us/step - loss: 1.5552 - accuracy: 0.9058
# Epoch 26/30
# 1875/1875 [==============================] - 2s 827us/step - loss: 1.5543 - accuracy: 0.9070
# Epoch 27/30
# 1875/1875 [==============================] - 2s 830us/step - loss: 1.5517 - accuracy: 0.9093
# Epoch 28/30
# 1875/1875 [==============================] - 2s 840us/step - loss: 1.5533 - accuracy: 0.9080
# Epoch 29/30
# 1875/1875 [==============================] - 2s 848us/step - loss: 1.5502 - accuracy: 0.9111
# Epoch 30/30
# 1875/1875 [==============================] - 2s 825us/step - loss: 1.5502 - accuracy: 0.9114

# %%
test_loss, test_accuracy = model.evaluate(test_dataset, steps=num_test_examples/32)
# Out:
# 312/312 [==============================] - 1s 1ms/step - loss: 1.5820 - accuracy: 0.8789

# %%
print("Accuracy on test dataset: ", test_accuracy)
# Out:
# Accuracy on test dataset:  0.8788999915122986

# %%
for test_images, test_labels in test_dataset.take(1):
    test_images = test_images.numpy()
    test_labels = test_labels.numpy()
    predictions = model.predict(test_images)

# %%
predictions.shape
# Out:
# (32, 10)

# %%
predictions[0]
# Out:
# array([1.1783782e-37, 5.0349516e-33, 6.4547201e-21, 3.7257151e-36,
#        1.0000000e+00, 0.0000000e+00, 1.7241618e-18, 0.0000000e+00,
#        1.2527493e-25, 0.0000000e+00], dtype=float32)

# %%
test_labels[0]
# Out:
# 4

# %%
np.argmax(predictions[0])
# Out:
# 4

# %%
def plot_image(i, predictions_array, true_labels, images):
    predictions_array, true_label, img = predictions_array[i], true_labels[i], images[i]
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(img[...,0], cmap=plt.cm.binary)
    
    predicted_label = np.argmax(predictions_array)
    color = "blue" if predicted_label == true_label else "red"
    plt.xlabel("{} {:2.0f}% ({})".format(
        class_names[predicted_label],
        100 * np.max(predictions_array),
        class_names[true_label]
    ))

# %%
def plot_value_array(i, predictions_array, true_label):
    predictions_array, true_label = predictions_array[i], true_label[i]
    plt.xticks(range(10))
    plt.yticks([])
    plt.grid(False)
    thisplot = plt.bar(range(10),predictions_array, color="#777777")
    plt.ylim([0,1])
    predicted_label = np.argmax(predictions_array)
    thisplot[predicted_label].set_color("red")
    thisplot[true_label].set_color("blue")

# %%
i = 0
plt.figure(figsize=(6,3))
plt.subplot(1,2,1)
plot_image(i, predictions, test_labels, test_images)
plt.subplot(1,2,2)
plot_value_array(i, predictions, test_labels)

# %%
i = 30
plt.figure(figsize=(6,3))
plt.subplot(1,2,1)
plot_image(i, predictions, test_labels, test_images)
plt.subplot(1,2,2)
plot_value_array(i, predictions, test_labels)

# %%
num_rows = 5
num_cols = 3
num_images = num_rows * num_cols
plt.figure(figsize=(2*2*num_rows, 2 * num_rows))
for i in range(num_images):
    plt.subplot(num_rows, 2* num_cols, 2*i + 1)
    plot_image(i, predictions, test_labels, test_images)
    plt.subplot(num_rows, 2* num_cols, 2*i + 2)
    plot_value_array(i, predictions, test_labels)
